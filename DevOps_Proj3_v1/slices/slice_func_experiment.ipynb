# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from joblib import load
import joblib

from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score


# import sys
# sys.path.append('..')
# from  data_processing.process_data import entire_data_processing, process_label, categorize_age,label_encoder, onehot_encoder,label_encoding_attribute

# %%
import os 
import logging

import pandas as pd
import numpy as np

from sklearn import preprocessing


logging.basicConfig(
    filename='./log',
    level=logging.INFO,
    filemode='a',
    format='%(name)s - %(levelname)s - %(asctime)s - %(message)s',
    datefmt='%d-%b-%y %H:%M:%S')


def get_age_group(age):
    if age < 18:
        return 'underage'
    elif (age >= 18) & (age < 60):
        return 'adult'
    else:
        return 'elder'


def get_salary_group(salary):
    if salary == '<=50K':
        return 1
    return 0


def process_label(df):
    df['salary'] = df['salary'].apply(get_salary_group)


def categorize_age(df):
    df['age'] = df['age'].apply(get_age_group)


def save_encoder_classes(path, attribute, le):
    if not os.path.exists(path):
        np.save(path, le.classes_)
        logging.info('init and save encoder classes_')


def label_encoder(df, attribute, training):
    le = preprocessing.LabelEncoder()
    
    if training:
        le.fit(list(set(df[attribute])))        
        save_encoder_classes(f'../data/label_encoders/{attribute}.npy', attribute, le)
    else:
        le.classes_ = np.load(f'../data/label_encoders/{attribute}.npy')
    df[attribute] = le.transform(df[attribute])


def label_encoding_attribute(df, training):
    label_encoder(df,'sex', training)
    label_encoder(df,'race', training)
    label_encoder(df,'occupation', training)
    label_encoder(df,'workclass', training)
    label_encoder(df,'marital-status', training)
    

def onehot_encoder(df, attribute, training):
    lb = preprocessing.LabelBinarizer()
    
    if training:
        lb.fit(list(set(df[attribute])))
        save_encoder_classes(f'../data/onehot_encoders/{attribute}.npy', attribute, lb)    
    else:
        lb.classes_ = np.load(f'../data/onehot_encoders/{attribute}.npy')
    return lb.transform(df[attribute])


def entire_data_processing(df, training):
    process_label(df)
    categorize_age(df)
    label_encoding_attribute(df, training)
    age_onehot_data = onehot_encoder(df, 'age', training)
    df.drop('age', axis=1, inplace=True)
    return np.concatenate([age_onehot_data, df.values], axis=1)

# %%
df
# Out:
#          age         workclass      marital-status         occupation  \
# 0      adult         State-gov       Never-married       Adm-clerical
# 1      adult  Self-emp-not-inc  Married-civ-spouse    Exec-managerial
# 2      adult           Private            Divorced  Handlers-cleaners
# 3      adult           Private  Married-civ-spouse  Handlers-cleaners
# 4      adult           Private  Married-civ-spouse     Prof-specialty
# ...      ...               ...                 ...                ...
# 20307  adult           Private       Never-married       Tech-support
# 20308  adult           Private       Never-married    Protective-serv
# 20309  adult           Private  Married-civ-spouse       Tech-support
# 20310  adult           Private             Widowed       Adm-clerical
# 20311  adult      Self-emp-inc  Married-civ-spouse    Exec-managerial
#
#                      race     sex  hours-per-week  salary
# 0                   White    Male              40       1
# 1                   White    Male              13       1
# 2                   White    Male              40       1
# 3                   Black    Male              40       1
# 4                   Black  Female              40       1
# ...                   ...     ...             ...     ...
# 20307  Asian-Pac-Islander    Male              11       1
# 20308               White    Male              40       1
# 20309               White  Female              38       1
# 20310               White  Female              40       1
# 20311               White  Female              40       0
#
# [20312 rows x 8 columns]

# %%
cat_features = [
    'age',
    'sex',
    'race',
    'occupation',
    'workclass',
    'marital-status',
    'salary'
]

# %%
path = '../data/census_cleaned.csv'

# %%
df = pd.read_csv(path)
process_label(df)
categorize_age(df)

# %%
cat_features.remove('salary')

# %%
cat_features
# Out:
# ['age', 'sex', 'race', 'occupation', 'workclass', 'marital-status']

# %%
_, test = train_test_split(df, test_size = 0.2, shuffle=True)

# %%
test
# Out:
#          age         workclass         marital-status        occupation  \
# 20259  adult           Private     Married-civ-spouse      Craft-repair
# 8256   adult           Private              Separated  Transport-moving
# 9530   adult         Local-gov               Divorced    Prof-specialty
# 3987   adult           Private          Never-married             Sales
# 17335  adult           Private               Divorced  Transport-moving
# ...      ...               ...                    ...               ...
# 410    adult           Private     Married-civ-spouse    Prof-specialty
# 15898  adult           Private  Married-spouse-absent   Exec-managerial
# 2716   elder           Private          Never-married     Other-service
# 9049   adult       Federal-gov     Married-civ-spouse      Adm-clerical
# 4319   adult  Self-emp-not-inc          Never-married      Adm-clerical
#
#         race     sex  hours-per-week  salary
# 20259  White    Male              48       1
# 8256   White    Male              60       1
# 9530   White  Female              57       1
# 3987   White    Male              65       1
# 17335  White    Male              56       0
# ...      ...     ...             ...     ...
# 410    White    Male              40       0
# 15898  White  Female              35       1
# 2716   White  Female              60       1
# 9049   White    Male              30       1
# 4319   Black  Female              20       1
#
# [4063 rows x 8 columns]

# %%
def encoder_attributes(df, training=False):
    label_encoding_attribute(df, training=False)
    age_onehot_data = onehot_encoder(df, 'age', training=False)
    
    df.drop('age', axis=1, inplace=True)
    return np.concatenate([age_onehot_data, df.values], axis=1)

# %%
all_scores_df = pd.DataFrame(
        columns=[
            "attribute",
            "category",
            "num_samples",
            "accuracy",
            "roc",
        ]
    )

# %%
cat_features1 = ['sex']

# %%
lgbm_model = joblib.load('../model/best_clf.pkl')

for attribute in cat_features:
    print(attribute)
    for category in test[attribute].unique():
        print(category)
        filtered_df = test[test[attribute] == category]
        n_samples = len(filtered_df)
        
        np_data = encoder_attributes(filtered_df)

        X = np_data[:, :-1]
        y = np_data[:, -1]
        
        if len(set(y)) == 1:
            accuracy = list(set(y))[0]
            roc_ = -1
        else:    
            y_pred = lgbm_model.predict(X)

            accuracy = int(accuracy_score(y, y_pred) * 10000)/10000
            roc_ = int(roc_auc_score(y,y_pred) * 10000)/10000
        
        scores_list = [
                attribute,
                category,
                n_samples,
                accuracy,
                roc_,
            ]
        
        scores_series = pd.Series(scores_list, index=all_scores_df.columns)

        # Add scores to DataFrame
        all_scores_df = all_scores_df.append(
            scores_series, ignore_index=True
        )

all_scores_df.to_csv('hey.csv',index=False)
# Out:
# age
# adult
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# elder
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# underage
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# sex
# Male
# Female
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# race
# White
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Asian-Pac-Islander
# Black
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# Amer-Indian-Eskimo
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Other
# occupation
# Craft-repair
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Transport-moving
# Prof-specialty
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Sales
# Exec-managerial
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Tech-support
# Priv-house-serv
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Other-service
# Adm-clerical
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Machine-op-inspct
# Handlers-cleaners
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Farming-fishing
# Protective-serv
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Armed-Forces
# workclass
# Private
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Local-gov
# Federal-gov
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Self-emp-not-inc
# State-gov
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Self-emp-inc
# Without-pay
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# marital-status
# Married-civ-spouse
# Separated
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Divorced
# Never-married
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# Widowed
# Married-spouse-absent
# Married-AF-spouse
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(
# /tmp/ipykernel_40618/3563696092.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attribute] = le.transform(df[attribute])
# /tmp/ipykernel_40618/145190739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('age', axis=1, inplace=True)
# /tmp/ipykernel_40618/1191359712.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(

# %%
def pre_process_data(path):
    df = pd.read_csv(path)
    np_data = entire_data_processing(df, True)
    
    y = np_data[:, -1]
    X = np_data[:, :-1]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)
    
    return X_test, y_test

# %%
def slices_scores(path):

# %%
# !touch slices.py
